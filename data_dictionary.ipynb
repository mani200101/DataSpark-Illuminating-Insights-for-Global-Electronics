# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\DELL\OneDrive\Desktop\projects_2\p2.Data_Dictionary.csv")
df
# Out:
#              Table           Field  \
# 0            Sales    Order Number
# 1            Sales       Line Item
# 2            Sales      Order Date
# 3            Sales   Delivery Date
# 4            Sales     CustomerKey
# 5            Sales        StoreKey
# 6            Sales      ProductKey
# 7            Sales        Quantity
# 8            Sales   Currency Code
# 9        Customers     CustomerKey
# 10       Customers          Gender
# 11       Customers            Name
# 12       Customers            City
# 13       Customers      State Code
# 14       Customers           State
# 15       Customers        Zip Code
# 16       Customers         Country
# 17       Customers       Continent
# 18       Customers        Birthday
# 19        Products      ProductKey
# 20        Products    Product Name
# 21        Products           Brand
# 22        Products           Color
# 23        Products   Unit Cost USD
# 24        Products  Unit Price USD
# ...

# %%
df.isnull().sum()
# Out:
# Table          0
# Field          0
# Description    0
# dtype: int64

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mysql.connector

# %%
mydf=mysql.connector.connect
(host="localhost",
user="root",
password="aziznagar09",
database="")

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
df.head(1)
# Out:
#    Table         Field               Description
# 0  Sales  Order Number  Unique ID for each order

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv('dictionary_data.csv')

# Convert order date to datetime format
#df = pd.to_datetime(df['Field'])

# Group data by month and calculate sales
monthly_sales = df.groupby(df['Field'].dt.to_period('M'))['Table'].sum()

# Plot sales trends
plt.figure(figsize=(10, 6))
monthly_sales.plot(kind='line', marker='o')
plt.title('Monthly Sales Trends', fontsize=16)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Total Sales', fontsize=12)
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 11
#       5 df = pd.read_csv('dictionary_data.csv')
#       7 # Convert order date to datetime format
#       8 #df = pd.to_datetime(df['Field'])
#       9
#      10 # Group data by month and calculate sales
# ---> 11 monthly_sales = df.groupby(df['Field'].dt.to_period('M'))['Table'].sum()
#      13 # Plot sales trends
#      14 plt.figure(figsize=(10, 6))
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# ...
